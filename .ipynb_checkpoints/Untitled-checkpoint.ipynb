# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
a = pd.Series(np.random.normal(6,3,100))
plt.plot(a)

# %%
a.hist()

# %%
x = pd.Series(np.random.normal(8,3,100))
y = pd.Series(np.random.normal(3,1,100))

# %%
plt.scatter(x,y)
plt.xlim(-10,10)
plt.ylim(-10,10)
# Out:
# (-10, 10)

# %%
x1 = pd.Series(np.random.normal(4,3,100))
y1 = pd.Series(np.random.normal(0,1,100))
plt.scatter(x1,y1) #Gato
plt.scatter(x,y) #Perro
plt.xlim(-10,10)
plt.ylim(-10,10)
# Out:
# (-10, 10)

# %%
from sklearn import datasets, svm, metrics
digits = datasets.load_digits()

# %%
print (digits.images[0])
# Out:
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]

# %%
import matplotlib.pyplot as plt 
for i in range (10):
    plt.subplot(5,5, i+1)
    plt.imshow(digits.images[i], cmap="gray")

# %%
X = digits.images[i]
print (X.shape)
# Out:
# (8, 8)

# %%
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(digits.images.reshape(1797,64))
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
print (X[0])
print (X[0].reshape(-1,1))

transformed = pca.transform(X[0]. re)
print (transformed.shape)
print (X[0])
print (transformed)
# Out:
# [ 0.  0. 11. 12.  0.  0.  0.  0.]
# [[ 0.]
#  [ 0.]
#  [11.]
#  [12.]
#  [ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-0b1713061410> in <module>
#       3
#       4
# ----> 5 print (transformed.shape)
#       6 print (X[0])
#       7 print (transformed)
#
# NameError: name 'transformed' is not defined
